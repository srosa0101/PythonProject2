# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import csv file
df = pd.read_csv("https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv")

# %%
#Goal is to compare Males and Femles from this Data

# %%
#Drop columns not needed
df.drop(['patient_nbr', 'race', 'weight', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'time_in_hospital', 'citoglipton'], axis=1, inplace=True)

# %%
df.drop(['diag_1', 'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'tolazamide', 'glyburide-metformin'], axis=1, inplace=True)

# %%
df
# Out:
#         encounter_id  gender      age payer_code         medical_specialty  \
# 0            2278392  Female   [0-10)          ?  Pediatrics-Endocrinology
# 1             149190  Female  [10-20)          ?                         ?
# 2              64410  Female  [20-30)          ?                         ?
# 3             500364    Male  [30-40)          ?                         ?
# 4              16680    Male  [40-50)          ?                         ?
# ...              ...     ...      ...        ...                       ...
# 101761     443847548    Male  [70-80)         MC                         ?
# 101762     443847782  Female  [80-90)         MC                         ?
# 101763     443854148    Male  [70-80)         MC                         ?
# 101764     443857166  Female  [80-90)         MC           Surgery-General
# 101765     443867222    Male  [70-80)          ?                         ?
#
#         num_lab_procedures  num_procedures  num_medications  \
# ...

# %%
df.drop(['age', 'payer_code', 'medical_specialty', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency'], axis=1, inplace=True)

# %%
df.drop(['number_inpatient', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 'troglitazone', 'examide'], axis=1, inplace=True)

# %%
df.drop(['glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'glipizide-metformin', 'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed'], axis=1, inplace=True)

# %%
df
# Out:
#         encounter_id  gender  diag_1  diag_2 diag_3  number_diagnoses  \
# 0            2278392  Female  250.83       ?      ?                 1
# 1             149190  Female     276  250.01    255                 9
# 2              64410  Female     648     250    V27                 6
# 3             500364    Male       8  250.43    403                 7
# 4              16680    Male     197     157    250                 5
# ...              ...     ...     ...     ...    ...               ...
# 101761     443847548    Male  250.13     291    458                 9
# 101762     443847782  Female     560     276    787                 9
# 101763     443854148    Male      38     590    296                13
# 101764     443857166  Female     996     285    998                 9
# 101765     443867222    Male     530     530    787                 9
#
#        max_glu_serum A1Cresult tolazamide insulin glyburide-metformin  \
# ...

# %%
df
# Out:
#         encounter_id  gender insulin readmitted
# 0            2278392  Female      No         NO
# 1             149190  Female      Up        >30
# 2              64410  Female      No         NO
# 3             500364    Male      Up         NO
# 4              16680    Male  Steady         NO
# ...              ...     ...     ...        ...
# 101761     443847548    Male    Down        >30
# 101762     443847782  Female  Steady         NO
# 101763     443854148    Male    Down         NO
# 101764     443857166  Female      Up         NO
# 101765     443867222    Male      No         NO
#
# [101766 rows x 4 columns]

# %%
df.drop(['readmitted'], axis=1, inplace=True)

# %%
df
# Out:
#         encounter_id  gender insulin
# 0            2278392  Female      No
# 1             149190  Female      Up
# 2              64410  Female      No
# 3             500364    Male      Up
# 4              16680    Male  Steady
# ...              ...     ...     ...
# 101761     443847548    Male    Down
# 101762     443847782  Female  Steady
# 101763     443854148    Male    Down
# 101764     443857166  Female      Up
# 101765     443867222    Male      No
#
# [101766 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['encounter_id'].plot(kind='hist', bins=20, title='encounter_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['insulin'].value_counts()
    for x_label, grp in df.groupby('gender')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('gender')
_ = plt.ylabel('insulin')

# %%
df.groupby(['insulin'])['gender'].count()
# Out:
# insulin
# Down      12218
# No        47383
# Steady    30849
# Up        11316
# Name: gender, dtype: int64

# %%
df.groupby(['gender'])["insulin"].count()
# Out:
# gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: insulin, dtype: int64

# %% [markdown]
# I wanted to compare the insulin levels between men and women for diabetes patients. In my finding, I see there is a larger population of women who have no insulin who are diabetes patients vs men.
